# %% [markdown]
# # **Web Scrape Tweets using SNTWITTER**

# %%
# !pip3 install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-fen0lf_x
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-fen0lf_x
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 0d824ab77334ed4ab6250e5e491171afeccfb298
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (2.27.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (4.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from snscrape==0.6.2.20230321.dev50+g0d824ab) (3.12.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->snscrape==0.6.2.20230321.dev50+g0d824ab) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape==0.6.2.20230321.dev50+g0d824ab) (1.7.1)

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('mental health since:2023-01-17 until:2023-06-17').get_items()):
    if i>5000:
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])

# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"])

tweets_df
# Out:
# <ipython-input-26-2fa3646d7068>:11: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669844061702766593
# WARNING:snscrape.modules.twitter:User 17639527 not found in user refs in card on tweet 1669844061702766593
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669834737966551041
# WARNING:snscrape.modules.twitter:User 2563362007 not found in user refs in card on tweet 1669834737966551041
# WARNING:snscrape.modules.twitter:Could not translate t.co card URL on tweet 1669815872809054208
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669810795037749251
# WARNING:snscrape.modules.twitter:User 14204245 not found in user refs in card on tweet 1669810795037749251
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669803971433709569
# WARNING:snscrape.modules.twitter:User 14204245 not found in user refs in card on tweet 1669803971433709569
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669795487627485202
# WARNING:snscrape.modules.twitter:User 14204245 not found in user refs in card on tweet 1669795487627485202
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669785743592398864
# WARNING:snscrape.modules.twitter:User 3562471 not found in user refs in card on tweet 1669785743592398864
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669740409302515712
# WARNING:snscrape.modules.twitter:Unavailable user in card on tweet 1669740409302515712
# WARNING:snscrape.modules.twitter:User 1062915983294300160 not found in user refs in card on tweet 1669740409302515712
# WARNING:snscrape.modules.twitter:User 1062915983294300160 not found in user refs in card on tweet 1669740409302515712
#                  User              Date Created  Number of Likes  \
# 0        stellamaree_ 2023-06-16 23:59:59+00:00                1
# 1     fullbackrevival 2023-06-16 23:59:51+00:00                1
# 2       dreamoflorien 2023-06-16 23:59:45+00:00                4
# 3         BeansalotJr 2023-06-16 23:59:37+00:00                0
# 4           WrangerJK 2023-06-16 23:59:37+00:00                0
# ...               ...                       ...              ...
# 4996    ItsMe50474936 2023-06-16 18:50:15+00:00                0
# 4997      devowilliAM 2023-06-16 18:50:12+00:00                0
# 4998     mariaisbackk 2023-06-16 18:50:12+00:00                3
# 4999     seattlebrief 2023-06-16 18:50:05+00:00                0
# 5000         marc316h 2023-06-16 18:50:00+00:00                1
#
#      Source of Tweet                                              Tweet
# 0               None                  Normalize mental health breaks!!!
# 1               None  @georgeoisie1 Absolutely not I have mental health
# 2               None  https://t.co/z0k5Z6C1pI\nhi all, i think im ta...
# 3               None  my mental health must be worse than I thought ...
# 4               None            @CODLeague @SimpXO Leave children alone
# ...              ...                                                ...
# 4996            None  @atalanta44 @DieMadTerf You're not. You are a ...
# 4997            None  @TheNBACentral Just don’t wave a gun around. M...
# 4998            None  Weil moini gemacht hat mach ich auch\n\nlooks:...
# 4999            None  Federal judge blasts WA officials for mental h...
# 5000            None  @POTUS Hope you focus on mental health of the ...
#
# [5001 rows x 5 columns]

# %% [markdown]
# # **Download Files**

# %%
# Save the DataFrame to a file on the Colab backend.
with open('tweets_df.csv', 'w') as f:
  f.write(tweets_df.to_csv())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cat df.json
# Out:
# cat: df.json: No such file or directory

# %%
# Download the file.
from google.colab import files
files.download('tweets_df.csv')

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## **Preprocessing data & Sentiment Analysis**

# %%
#Importing libraries
import numpy as np
import pandas as pd

# %%
tweets_df.head(50)
# Out:
#                User              Date Created  Number of Likes  \
# 0      stellamaree_ 2023-06-16 23:59:59+00:00                1
# 1   fullbackrevival 2023-06-16 23:59:51+00:00                1
# 2     dreamoflorien 2023-06-16 23:59:45+00:00                4
# 3       BeansalotJr 2023-06-16 23:59:37+00:00                0
# 4         WrangerJK 2023-06-16 23:59:37+00:00                0
# 5        mintsroses 2023-06-16 23:59:37+00:00                1
# 6        saddayitis 2023-06-16 23:59:32+00:00                2
# 7         matt02922 2023-06-16 23:59:25+00:00                0
# 8    wolfofballmeat 2023-06-16 23:59:21+00:00                0
# 9       Crownescent 2023-06-16 23:59:16+00:00                1
# 10   Scarfacesaints 2023-06-16 23:59:12+00:00                0
# 11        barcodext 2023-06-16 23:59:05+00:00                0
# 12         eeimaann 2023-06-16 23:59:03+00:00                1
# 13       pigeonlore 2023-06-16 23:59:01+00:00                1
# 14           LBerbs 2023-06-16 23:59:01+00:00                0
# 15  TrainingMindful 2023-06-16 23:59:00+00:00                7
# 16         Hermi03_ 2023-06-16 23:58:57+00:00                0
# 17      ggardengirl 2023-06-16 23:58:56+00:00                2
# 18    Benign_Molten 2023-06-16 23:58:51+00:00                0
# 19     nursedebates 2023-06-16 23:58:47+00:00                2
# 20    Artemesia1593 2023-06-16 23:58:46+00:00                0
# 21     finelineerry 2023-06-16 23:58:44+00:00                4
# 22     collegekid23 2023-06-16 23:58:38+00:00                0
# 23    ineighborhood 2023-06-16 23:58:30+00:00                1
# 24      SRawstein87 2023-06-16 23:58:28+00:00                1
# 25     TinyGreenNBS 2023-06-16 23:58:16+00:00                0
# 26     typicalaufey 2023-06-16 23:58:14+00:00                0
# 27     MEO_inventor 2023-06-16 23:58:03+00:00                1
# 28   COVIDBurnerAcc 2023-06-16 23:57:59+00:00                0
# 29       Russty1105 2023-06-16 23:57:57+00:00                0
# 30         dingvald 2023-06-16 23:57:53+00:00                0
# 31        GACEB_829 2023-06-16 23:57:52+00:00                0
# 32  BeautyAndLiquor 2023-06-16 23:57:44+00:00                0
# 33        He8889jle 2023-06-16 23:57:42+00:00                2
# 34  raphealsamuel64 2023-06-16 23:57:37+00:00                1
# 35     meetministry 2023-06-16 23:57:35+00:00                0
# 36  Frank_Butterfly 2023-06-16 23:57:27+00:00                6
# 37   TrixiebelleBMC 2023-06-16 23:57:23+00:00                2
# 38      88IsabelleR 2023-06-16 23:57:18+00:00                1
# 39   likeitorlumpit 2023-06-16 23:57:16+00:00                0
# 40     LadyLiltalen 2023-06-16 23:56:54+00:00                4
# 41       mallyvlone 2023-06-16 23:56:52+00:00                0
# 42    JonSchreifels 2023-06-16 23:56:41+00:00                2
# 43    777Nickjacobs 2023-06-16 23:56:31+00:00                0
# 44      grizzlykid4 2023-06-16 23:56:29+00:00                0
# 45    ThinkBookClub 2023-06-16 23:56:19+00:00                0
# 46  Pearlbu13205231 2023-06-16 23:56:14+00:00                0
# 47  Hayesarttherapy 2023-06-16 23:56:12+00:00                2
# 48         Drops_It 2023-06-16 23:56:02+00:00                0
# 49  barcelonababy12 2023-06-16 23:56:00+00:00                0
#
#    Source of Tweet                                              Tweet
# 0             None                  Normalize mental health breaks!!!
# 1             None  @georgeoisie1 Absolutely not I have mental health
# 2             None  https://t.co/z0k5Z6C1pI\nhi all, i think im ta...
# 3             None  my mental health must be worse than I thought ...
# 4             None            @CODLeague @SimpXO Leave children alone
# 5             None  I have so many ghostfang fanart ideas in my he...
# 6             None  @tammyri93981707 @bobmackin Hey wasn't Jennife...
# 7             None  @C0alhands @hutchinson That’s a lot of words t...
# 8             None  @ArtByJenk @fewocious @windsandnstars He's hav...
# 9             None  #mentalhealth @KelliDrenner #StayPositive Ment...
# 10            None  @beautifulwhips3 @franturo @ShannonSharpe So t...
# 11            None  @WhiteHouse Darrell Brooks taught us you don’t...
# 12            None  ✨✨✨✨✨✨✨✨\n✨  mental health is    ✨\n✨ just as ...
# 13            None  @meghaverma_art no but seriously during mens m...
# 14            None  @movingamputees @jasonsudeikis Better for his ...
# 15            None  “Our painful emotions are rooted in the ego.” ...
# 16            None  Rate yourself\nLooks: 5/10\nCreativity: 8/10\n...
# 17            None  @shaunacore @abbyandrsns not really so i think...
# 18            None  @JWillsNH @Alex__G88 @Pickettsburgh8 Thanks fo...
# 19            None  @BBCScotlandNews Snp supporter. But j baillie?...
# 20            None  @VivekGRamaswamy The brutality of Republican i...
# 21            None  hi @Harry_Styles i hope ur well! \n\ni just wa...
# 22            None  I’m managing my own mental health I can’t give...
# 23            None  #MentalHealthAwareness #mentalhealth \n#Suicid...
# 24            None  @Please_StandBye @ThmsHoward @FoxNews Excuse m...
# 25            None  Omg lol... "I hope we don't see him on social ...
# 26            None  And yeah, I tried to get better for someone, f...
# 27            None  @cluesdotlife as you're a mental health writer...
# 28            None  @meghaverma_art I say this with all sincerity:...
# 29            None  @drDavidKeegan @AHS_media I know many doctors ...
# 30            None  @SurreyMayor Instead of paying SPS severance w...
# 31            None  #SmackDown \n\nBeen a long week. My mental hea...
# 32            None  damn Summer 💔 we was just rapping about how we...
# 33            None  @drDavidKeegan @GlobalCalgary Its not mental h...
# 34            None  @EiseleTanninman Seek professional mental heal...
# 35            None  The Gospel of Mental Health | Dr. Anthony Chor...
# 36            None  For those who need a laugh. #Fun #StarWars #Me...
# 37            None  @happy_foxxy "I would be screaming in grief, t...
# 38            None  @second_sailing @BulwarkOnline This piece caug...
# 39            None  @RandyEischer @RonPlacone I was on welfare tha...
# 40            None  I had a mental health day today,  touched some...
# 41            None                     is it worth your mental health
# 42            None  @straczynski I don't think there are many thin...
# 43            None  @ABC7 What grown adult dresses up in makeup &a...
# 44            None  The Adventures Of Jim Cornette https://t.co/nZ...
# 45            None  1.2/, This idea raises questions about the aut...
# 46            None  @The_Trump_Train He has mental health issues h...
# 47            None  Anxiety-Reducing Art Therapy Prompts to Try Ou...
# 48            None  @antiracismNL This appears to be a premeditate...
# 49            None  If u or someone u know are having suicidal tho...

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User             5001 non-null   object
#  1   Date Created     5001 non-null   datetime64[ns, UTC]
#  2   Number of Likes  5001 non-null   int64
#  3   Source of Tweet  0 non-null      object
#  4   Tweet            5001 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(1), object(3)
# memory usage: 195.5+ KB

# %%
# identify missing value
tweets_df.isna().sum()
# Out:
# User                  0
# Date Created          0
# Number of Likes       0
# Source of Tweet    5001
# Tweet                 0
# dtype: int64

# %%
# delete 'Source of Tweet' column
del tweets_df['Source of Tweet']

# %%
# identify missing value
tweets_df.isna().sum()
# Out:
# User               0
# Date Created       0
# Number of Likes    0
# Tweet              0
# dtype: int64

# %%
tweets_df.head(10)
# Out:
#               User              Date Created  Number of Likes  \
# 0     stellamaree_ 2023-06-16 23:59:59+00:00                1
# 1  fullbackrevival 2023-06-16 23:59:51+00:00                1
# 2    dreamoflorien 2023-06-16 23:59:45+00:00                4
# 3      BeansalotJr 2023-06-16 23:59:37+00:00                0
# 4        WrangerJK 2023-06-16 23:59:37+00:00                0
# 5       mintsroses 2023-06-16 23:59:37+00:00                1
# 6       saddayitis 2023-06-16 23:59:32+00:00                2
# 7        matt02922 2023-06-16 23:59:25+00:00                0
# 8   wolfofballmeat 2023-06-16 23:59:21+00:00                0
# 9      Crownescent 2023-06-16 23:59:16+00:00                1
#
#                                                Tweet
# 0                  Normalize mental health breaks!!!
# 1  @georgeoisie1 Absolutely not I have mental health
# 2  https://t.co/z0k5Z6C1pI\nhi all, i think im ta...
# 3  my mental health must be worse than I thought ...
# 4            @CODLeague @SimpXO Leave children alone
# 5  I have so many ghostfang fanart ideas in my he...
# 6  @tammyri93981707 @bobmackin Hey wasn't Jennife...
# 7  @C0alhands @hutchinson That’s a lot of words t...
# 8  @ArtByJenk @fewocious @windsandnstars He's hav...
# 9  #mentalhealth @KelliDrenner #StayPositive Ment...

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text(text):
    # Text cleaning
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\d+', '', text)  # Remove numbers

    # Tokenization
    tokens = nltk.word_tokenize(text)

    # Stopword removal
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.lower() not in stop_words]

    # Lowercasing
    tokens = [word.lower() for word in tokens]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Reconstruct the preprocessed text
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

def get_sentiment(text):
  blob = TextBlob(text)
  polarity = blob.sentiment.polarity
  if polarity > 0:
    return "Positive"
  elif polarity < 0:
    return "Negative"
  else:
    return "Neutral"

def get_polarity(text):
  blob = TextBlob(text)
  polarity = blob.sentiment.polarity
  return polarity

# Preprocess the 'Tweet' column and add 'CleanedTweet' column
Cleanedtweets_df = tweets_df.copy()
Cleanedtweets_df['CleanedTweet'] = Cleanedtweets_df['Tweet'].apply(preprocess_text)

# Perform sentiment analysis on the preprocessed text
Cleanedtweets_df['Sentiment'] = Cleanedtweets_df['CleanedTweet'].apply(get_sentiment)
Cleanedtweets_df['Polarity'] = Cleanedtweets_df['CleanedTweet'].apply(get_polarity)

# Drop the original 'Tweet' column
Cleanedtweets_df.drop('Tweet', axis=1, inplace=True)

# View the updated DataFrame
Cleanedtweets_df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                  User              Date Created  Number of Likes  \
# 0        stellamaree_ 2023-06-16 23:59:59+00:00                1
# 1     fullbackrevival 2023-06-16 23:59:51+00:00                1
# 2       dreamoflorien 2023-06-16 23:59:45+00:00                4
# 3         BeansalotJr 2023-06-16 23:59:37+00:00                0
# 4           WrangerJK 2023-06-16 23:59:37+00:00                0
# ...               ...                       ...              ...
# 4996    ItsMe50474936 2023-06-16 18:50:15+00:00                0
# 4997      devowilliAM 2023-06-16 18:50:12+00:00                0
# 4998     mariaisbackk 2023-06-16 18:50:12+00:00                3
# 4999     seattlebrief 2023-06-16 18:50:05+00:00                0
# 5000         marc316h 2023-06-16 18:50:00+00:00                1
#
#                                            CleanedTweet Sentiment  Polarity
# 0                         normalize mental health break  Negative -0.100000
# 1                  georgeoisie absolutely mental health  Negative -0.100000
# 2     hi think im taking hiatus rp safety mental hea...  Negative -0.100000
# 3     mental health must worse thought even audacity...  Negative -0.250000
# 4                    codleague simpxo leave child alone   Neutral  0.000000
# ...                                                 ...       ...       ...
# 4996  atalanta diemadterf youre woman need get corre...  Negative -0.100000
# 4997  thenbacentral dont wave gun around mental heal...   Neutral  0.000000
# 4998  weil moini gemacht hat mach ich auch look crea...  Negative -0.033333
# 4999  federal judge blast wa official mental health ...  Negative -0.208333
# 5000  potus hope focus mental health troubled use to...  Negative -0.300000
#
# [5001 rows x 6 columns]

# %%
Cleanedtweets_df.head(10)
# Out:
#               User              Date Created  Number of Likes  \
# 0     stellamaree_ 2023-06-16 23:59:59+00:00                1
# 1  fullbackrevival 2023-06-16 23:59:51+00:00                1
# 2    dreamoflorien 2023-06-16 23:59:45+00:00                4
# 3      BeansalotJr 2023-06-16 23:59:37+00:00                0
# 4        WrangerJK 2023-06-16 23:59:37+00:00                0
# 5       mintsroses 2023-06-16 23:59:37+00:00                1
# 6       saddayitis 2023-06-16 23:59:32+00:00                2
# 7        matt02922 2023-06-16 23:59:25+00:00                0
# 8   wolfofballmeat 2023-06-16 23:59:21+00:00                0
# 9      Crownescent 2023-06-16 23:59:16+00:00                1
#
#                                         CleanedTweet Sentiment  Polarity
# 0                      normalize mental health break  Negative -0.100000
# 1               georgeoisie absolutely mental health  Negative -0.100000
# 2  hi think im taking hiatus rp safety mental hea...  Negative -0.100000
# 3  mental health must worse thought even audacity...  Negative -0.250000
# 4                 codleague simpxo leave child alone   Neutral  0.000000
# 5  many ghostfang fanart idea head im busy workin...  Positive  0.200000
# 6  tammyri bobmackin hey wasnt jennifer whiteside...  Negative -0.100000
# 7  calhands hutchinson thats lot word say absolut...  Positive  0.141667
# 8  artbyjenk fewocious windsandnstars he mental h...  Negative -0.100000
# 9  mentalhealth kellidrenner staypositive mental ...  Positive  0.050000

# %%
# Save the DataFrame to a file on the Colab backend.
with open('Cleanedtweets_df.csv', 'w') as f:
  f.write(Cleanedtweets_df.to_csv())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Download the file.
from google.colab import files
files.download('Cleanedtweets_df.csv')

# %% [markdown]
# ## **Data Visualization**

# %%
import matplotlib.pyplot as plt

# Perform sentiment analysis on the preprocessed text
Cleanedtweets_df['Sentiment'] = Cleanedtweets_df['CleanedTweet'].apply(get_sentiment)

# Plot the sentiment distribution
sentiment_counts = Cleanedtweets_df['Sentiment'].value_counts()
labels = sentiment_counts.index

plt.pie(sentiment_counts, labels=labels, autopct="%1.1f%%")
plt.title("Sentiment on Tweets regarding Mental Health on Twitter")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert Unix timestamps to datetime format
Cleanedtweets_df['Date Created'] = pd.to_datetime(Cleanedtweets_df['Date Created'], unit='ms')

# Extract hour from 'Date Created' column
Cleanedtweets_df['Hour'] = Cleanedtweets_df['Date Created'].dt.hour

# Categorize time of day
def categorize_time(hour):
    if 6 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 18:
        return 'Afternoon'
    elif 18 <= hour < 24:
        return 'Evening'
    else:
        return 'Night'

# Apply time categorization
Cleanedtweets_df['TimeOfDay'] = Cleanedtweets_df['Hour'].apply(categorize_time)

# Count the occurrences of each time of day
time_counts = Cleanedtweets_df['TimeOfDay'].value_counts()

# Create a bar chart
plt.bar(time_counts.index, time_counts.values)
plt.title('Distribution of Time of Day in Tweets')
plt.xlabel('Time of Day')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt

sentiment_scores = Cleanedtweets_df['Sentiment']

plt.hist(sentiment_scores, bins=10, edgecolor='black')
plt.title("Distribution of Sentiment Scores")
plt.xlabel("Sentiment Score")
plt.ylabel("Count")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a dataframe named `tweets_df` with the required columns

# Group the data by sentiment and count the number of tweets in each category
sentiment_counts = Cleanedtweets_df['Polarity'].value_counts()

# Plot the sentiment distribution
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.title('Distribution of Sentiment on Twitter')
plt.show()

# Calculate the average number of likes per sentiment category
avg_likes = Cleanedtweets_df.groupby('Polarity')['Number of Likes'].mean()

# Plot the average number of likes per sentiment category
plt.bar(avg_likes.index, avg_likes.values)
plt.xlabel('Sentiment')
plt.ylabel('Average Number of Likes')
plt.title('Average Number of Likes by Sentiment')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Combine all the preprocessed texts into a single string
all_text = ' '.join(Cleanedtweets_df['CleanedTweet'])

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400).generate(all_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tweets')
plt.show()

# %%
import matplotlib.pyplot as plt


# Group the data by date and calculate the total number of likes for each day
likes_by_date = Cleanedtweets_df.groupby('Date Created')['Number of Likes'].sum()

# Plot the likes over time using a line chart
likes_by_date.plot(kind='line', figsize=(10, 6))
plt.xlabel('Date')
plt.ylabel('Number of Likes')
plt.title('Likes Over Time')
plt.show()
