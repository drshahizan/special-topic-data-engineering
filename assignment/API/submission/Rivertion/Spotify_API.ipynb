# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/special-topic-data-engineering/blob/main/Rivertion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import requests

# %%
url = 'https://accounts.spotify.com/api/token'
data = {
    'grant_type': 'client_credentials',
    'client_id': '39d34046ceb846029127453746e14629',
    'client_secret': 'c263ba986458411fbd24c41fd3b504e3'
}
headers = {
    'Content-Type': 'application/x-www-form-urlencoded'
}

response = requests.post(url, data=data, headers=headers)

print(response.json())
# Out:
# {'access_token': 'BQCg1QL1zKvt741T7kDn93tECz4IxaIzKqbbFZJg7CByhk9bc8an4mlwDYCdyOKxtUPCLCZFWTluCO3OYSOLVsAB-FanoEFPgf5qsgrHs6PTW4SKUQd5', 'token_type': 'Bearer', 'expires_in': 3600}

# %%
url = 'https://api.spotify.com/v1/search?type=track&q=artist:Taylor Swift'
headers = {
    'Authorization': 'Bearer BQCg1QL1zKvt741T7kDn93tECz4IxaIzKqbbFZJg7CByhk9bc8an4mlwDYCdyOKxtUPCLCZFWTluCO3OYSOLVsAB-FanoEFPgf5qsgrHs6PTW4SKUQd5'
}

response = requests.get(url, headers=headers)

data=response.json()

print(data)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3ATaylor+Swift&type=track&offset=0&limit=20', 'items': [{'album': {'album_group': 'album', 'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'}, 'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02', 'id': '06HL4z0CvFAxyc27GXpf02', 'name': 'Taylor Swift', 'type': 'artist', 'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'ET', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'K
# ...

# %%
# Save data to CSV
with open('/content/drive/MyDrive/Taylor_Swift.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    # Write the header row
    writer.writerow(['name', 'popularity', 'album', 'track_url'])
    # Write each track to a new row
    for track in data['tracks']['items']:
        name = track['name']
        popularity = track['popularity']
        album_name = track['album']['name']
        track_url = track['external_urls']['spotify']
        writer.writerow([name, popularity, album_name, track_url])

print('Taylor_Swift.csv')
# Out:
# Taylor_Swift.csv

# %%
# !pip install pymongo
from pymongo import MongoClient
client = MongoClient("mongodb+srv://DinieHazim:diniehazim@cluster0.nd5oq2m.mongodb.net/test");
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.1/492.1 KB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 KB 24.7 MB/s eta 0:00:00
# ...

# %%
import pymongo

# Connect to MongoDB
client = pymongo.MongoClient('mongodb+srv://DinieHazim:diniehazim@cluster0.nd5oq2m.mongodb.net/test')
db = client['Rivertion']
collection = db['Taylor_Swift']

# Open the CSV file and iterate through each row
try:
    with open('/content/drive/MyDrive/Taylor_Swift.csv', 'r', newline='', encoding='utf-8') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            # Insert the record into MongoDB
            collection.insert_one({
                'name': row['name'],
                'popularity': int(row['popularity']),
                'album': row['album'],
                'track_url': row['track_url']
            })
    print("Upload successful.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Upload successful.
