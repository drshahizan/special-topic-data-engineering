# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/special-topic-data-engineering/blob/main/assignment/data-scraping/submission/part2/CodeX/GS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32002 sha256=c6ec752ad40087e0aaecde176f039643d5328305b49b00edd554c450b7170a2a
#   Stored in directory: /root/.cache/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
# Successfully built google-search-results
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_scholar_author",
  "author_id": "TZmzaW4AAAAJ",  # Author ID for lecturer in faculty of computing UTM
  "num": 100,
  "api_key": "592b22c1ce7080ab7e48819dd55666563ffa906acd09c3eb0f36d8683bc2ffe1"
}

search = GoogleSearch(params)
results = search.get_dict()
author = results["author"]

data = []
for response in results['articles']:
    title = response['title']
    authors = response.get('authors', [])
    year = response.get('year', None)
    link = response['link']


    data.append({
        'Title': title,
        'Authors': authors,
        'Year': year,
        'Link': link,

    })

for item in data:
    print('Title:', item['Title'])
    print('Authors:', item['Authors'])
    print('Year:', item['Year'])
    print('Link:', item['Link'])

    print('\n')
# Out:
# Title: Effect of early tranexamic acid administration on mortality, hysterectomy, and other morbidities in women with post-partum haemorrhage (WOMAN): an international, randomised …
# Authors: H Shakur, I Roberts, B Fawole, R Chaudhri, M El-Sheikh, A Akintan, ...
# Year: 2017
# Link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=TZmzaW4AAAAJ&pagesize=100&citation_for_view=TZmzaW4AAAAJ:fbc8zXXH2BUC
#
#
# Title: Classification with class imbalance problem
# Authors: A Ali, SM Shamsuddin, AL Ralescu
# Year: 2013
# Link: https://scholar.google.com/citations?view_op=view_citation&hl=en&user=TZmzaW4AAAAJ&pagesize=100&citation_for_view=TZmzaW4AAAAJ:2osOgNQ5qMEC
#
#
# Title: Perioperative patient outcomes in the African Surgical Outcomes Study: a 7-day prospective observational cohort study
# Authors: BM Biccard, TE Madiba, HL Kluyts, DM Munlemvo, FD Madzimbamuto, ...
# Year: 2018
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)
df.to_csv('google_scholar_articles_DR_Aida_Ali.csv', index=False)

# %%
df
# Out:
#                                                 Title  \
# 0   Effect of early tranexamic acid administration...
# 1         Classification with class imbalance problem
# 2   Perioperative patient outcomes in the African ...
# 3   Antioxidant requirements for bovine oocytes va...
# 4   Rosemary leaves as a dietary supplement for gr...
# ..                                                ...
# 95  Biomass and carbon stocks in Schima superba do...
# 96  Study of static voltage stability index as an ...
# 97  The Debye screening length in ultrathin films ...
# 98  Heritability estimates for winter hardiness in...
# 99  Handling imbalanced ratio for class imbalance ...
#
#                                               Authors  Year  \
# 0   H Shakur, I Roberts, B Fawole, R Chaudhri, M E...  2017
# 1                    A Ali, SM Shamsuddin, AL Ralescu  2013
# 2   BM Biccard, TE Madiba, HL Kluyts, DM Munlemvo,...  2018
# 3                      AA Ali, JF Bilodeau, MA Sirard  2003
# ...
