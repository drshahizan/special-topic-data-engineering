# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/special-topic-data-engineering/blob/main/assignment/data-scraping/submission/part2/DataAce/DS_GoogleScholar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests

# %%
from urllib.request import Request, urlopen

# %%
root = 'https://scholar.google.com/'
link = 'https://scholar.google.com/citations?view_op=view_org&org=14000212712167289655&hl=en&oi=io'

# %%
req = Request(link, headers={'User-Agent': 'Mozilla/5.0'})

# %%
webpage = urlopen(req).read()
print(webpage)
# Out:
# b'<!doctype html><html><head><title>Profiles</title><meta http-equiv="Content-Type" content="text/html;charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="referrer" content="always"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=2"><meta name="format-detection" content="telephone=no"><link rel="shortcut icon" href="/favicon.ico"><style>html,body,form,table,div,h1,h2,h3,h4,h5,h6,img,ol,ul,li,button{margin:0;padding:0;border:0;}table{border-collapse:collapse;border-width:0;empty-cells:show;}html,body{height:100%}#gs_top{position:relative;box-sizing:border-box;min-height:100%;min-width:964px;-webkit-tap-highlight-color:rgba(0,0,0,0);}#gs_top>*:not(#x){-webkit-tap-highlight-color:rgba(204,204,204,.5);}.gs_el_ph #gs_top,.gs_el_ta #gs_top{min-width:320px;}#gs_top.gs_nscl{position:fixed;width:100%;}body,td,input,button{font-size:13px;font-family:Arial,sans-serif;line-height:1.24;}body{background:#fff;color:#222;-webkit-text-size-adjust:100%;-moz-text-size-adjust:none;}.gs_gray{color:#777777}.gs_red{color:#dd4b39}.gs_grn{color:#006621}.gs_lil{font-size:11px}.gs_med{font-size:16px}.gs_hlt{font-weight:bold;}a:link{color:#1a0dab;text-decoration:none}a:visited{color:#660099;text-decoration:none}a:hover,a:hover .gs_lbl{text-decoration:underline}a:active,a:active .gs_lbl,a .gs_lbl:active{color:#d14836}.gs_el_tc a:hover,.gs_el_tc a:hover .gs_lbl{text-decoration:none}.gs_pfcs a:focus,.gs_pfcs button:focus,.gs_pfcs input:focus,.gs_pfcs label:focus{outline:none}.gs_a,.gs_a a:link,.gs_a a:visited{color:#006621}.gs_a a:active{color:#d14836}a.gs_fl:link,.gs_fl a:link{color:#1a0dab}a.gs_fl:visited,.gs_fl a:visited{color:#660099}a.gs_fl:active,.gs_fl a:active{color:#d14836}.gs_fl{color:#777777}.gs_ctc,.gs_ctu{vertical-align:middle;font-size:11px;font-weight:bold}.gs_ctc{color:#1a0dab}.gs_ctg,.gs_ctg2{font-size:13px;font-weight:bold}.gs_ctg{color:#1a0dab}a.gs_pda,.gs_pda a{padding:7px 0 5px 0}.gs_alrt{background:#f9edbe;border:1px solid #f0c36d;padding:0 16px;text-align:center;box-shadow:0 2px 4px rgba(0,0,0,.2);border-radius:2px;}.gs_alrt:empty{display:none;}.gs_spc{display:inline-block;width:12px}.gs_br{width:0;font-size:0}.gs_ibl{display:inline-block;}.gs_scl:after{content:"";display:table;clear:both;}.gs_ind{padding-left:8px;text-indent:-8px}.gs_ico,.gs_icm{display:inline-block;background:no-repeat url(/intl/en/scholar/images/1x/sprite_20161020.png);background-position:-23px -161px;background-size:169px;width:21px;height:21px;}@media(-webkit-min-device-pixel-ratio:1.5),(min-resolution:144dpi){.gs_ico,.gs_icm{background-image:url(/intl/en/scholar/images/2x/sprite_20161020.png);}}.gs_el_ta .gs_nta,.gs_ota,.gs_el_ph .gs_nph,.gs_oph{display:none}.gs_el_ta .gs_ota,.gs_el_ph .gs_oph{display:inline}.gs_el_ta div.gs_ota,.gs_el_ph div.gs_oph{display:block}.gs_sth_g{visibility:hidden;max-height:0;}.gs_sth_vis .gs_sth_g{max-height:1000px;}.gs_sth_vis .gs_sth_b{position:fixed;top:0;}.gs_sth_trk .gs_sth_b{position:absolute;top:auto;}@keyframes gs_anm_spin{0%{transform:rotate(0deg);}100%{transform:rotate(360deg);}}.gs_rimg{display:block;background-color:#e5e5e5;border-radius:50%;overflow:hidden;position:relative;z-index:1;}.gs_rimg>img{position:absolute;margin:auto;left:0;top:0;bottom:0;right:0;}.gs_in_txtw{display:inline-block;vertical-align:middle;}.gs_in_txtb{display:block;}.gs_in_txt{color:#000;background-color:#fff;font-size:16px;box-sizing:border-box;height:29px;line-height:23px;border:1px solid #d9d9d9;border-top-color:#c0c0c0;padding:3px 6px 1px 8px;border-radius:1px;outline:none;-webkit-appearance:none;-moz-appearance:none;}.gs_el_tc .gs_in_txt{font-size:18px;}.gs_in_txtb .gs_in_txt{width:100%;}.gs_in_rnd .gs_in_txt{border-radius:14.5px;padding:3px 12px 1px 12px;}.gs_in_txt:hover{border-color:#b9b9b9;border-top-color:#a0a0a0;box-shadow:inset 0 1px 2px rgba(0,0,0,.1);}.gs_in_txte .gs_in_txt{border-color:#dd4b39;}.gs_in_txt:focus{border-color:#4d90fe;box-shadow:inset 0 1px 2px  ...

# %%
data = []

# %%
with requests.Session() as c:
  soup = BeautifulSoup(webpage, 'html5lib')
  for item in soup.find_all('div', attrs = {'class': 'gsc_1usr'}):
    # print(item)
    name = (item.find('h3', attrs = {'class': 'gs_ai_name'}).get_text())
    print(name)
    desc = (item.find('div', attrs = {'class': 'gs_ai_aff'}).get_text())
    print(desc)
    v_email = (item.find('div', attrs = {'class': 'gs_ai_eml'}).get_text())
    email = (v_email.split('Verified email at ')[1])
    print(email)
    cited= (item.find('div', attrs = {'class': 'gs_ai_cby'}).get_text())
    cby = (cited.split('Cited by ')[1])
    print(cby)

    for gs_ai_int in item.find_all('div', {'class': 'gs_ai_int'}):
        labels = [link.text for link in gs_ai_int.find_all('a', {'class': 'gs_ai_one_int'})]
        print(labels)
      
    raw_link = (item.find('a', href = True)['href'])
    link = 'https://scholar.google.com/' + raw_link
    print(link)

    data.append({'Name': name, 'Description': desc, 'Verified Email at': email, 'Cited By': cby, 'Expertise': labels, 'Link': link})
# Out:
# Ahmad Fauzi Ismail
# Advanced Membrane Technology Research Centre, Universiti Teknologi Malaysia
# utm.my
# 64516
# ['membrane technology', 'nanostructured materials', 'hemodialysis', 'reverse osmosis', 'fuel cell']
# https://scholar.google.com//citations?hl=en&user=8VLNIb0AAAAJ
# Ts. Dr. Haslinda Mohamed Kamar
# Associate Professor, School of Mechanical Engineering, Universiti Teknologi Malaysia
# utm.my
# 43151
# ['Thermodynamics', 'Heat transfer', 'Thermal comfort', 'Indoor air quality', 'HVAC']
# https://scholar.google.com//citations?hl=en&user=1oiBvlQAAAAJ
# Muhammad Zulkarnain Abd Rahman
# Universiti Teknologi Malaysia, Delft university of technology
# utm.my
# 16831
# ['Remote Sensing']
# https://scholar.google.com//citations?hl=en&user=0ndPGrkAAAAJ
# Ir Dr Nor Aishah Saidina Amin
# Professor, Universiti Teknologi Malaysia
# utm.my
# 16025
# ['Applied catalysis', 'reaction engineering', 'biomass conversion', 'CO2 utilization', 'hydrogen production']
# https://scholar.google.com//citations?hl=en&user=0KAkq9MAAAAJ
# Mukhlis A Rahman
# Advanced Membrane Technology Research Centre, Universiti Teknologi Malaysia
# petroleum.utm.my
# 15964
# ['Membrane Technology', 'Ceramic Membrane']
# https://scholar.google.com//citations?hl=en&user=O5D_MxAAAAAJ
# Dr. Zainal Salam
# Professor of Power Electronics, Universiti Teknologi Malaysia
# fke.utm.my
# 15391
# ['Power Electronics', 'Energy', 'Solar', 'Photovoltaic']
# https://scholar.google.com//citations?hl=en&user=L48PgBQAAAAJ
# Shamsuddin Shahid
# Associate Professor, Universiti Teknologi Malaysia
# utm.my
# 15177
# ['Water resources', 'Climate Change', 'Statistical hydrology', 'Groundwater hydrology', 'Hydrological disasters']
# https://scholar.google.com//citations?hl=en&user=lCUDYyYAAAAJ
# abdul halim mohamed yatim
# Universiti teknologi malaysia
# fke.utm.my
# 14906
# ['Power electronics', 'electrical drives', 'renewable energy']
# https://scholar.google.com//citations?hl=en&user=cfZOjo0AAAAJ
# WJ Lau (Woei-Jye Lau)
# Advanced Membrane Technology Research Centre, Universiti Teknologi Malaysia
# utm.my
# 14311
# ['Membrane', 'Thin Film Nanocomposite', 'Reverse Osmosis', 'Nanofiltration', 'Water/Wastewater Purification']
# https://scholar.google.com//citations?hl=en&user=ZHLg4wMAAAAJ
# Arshad Ahmad
# Universiti Teknologi Malaysia
# utm.my
# 13145
# ['Process Modeling', 'Process Safety', 'Process Control & Optimization', 'Process Intensification', 'Hydrogen & Fuel Cell']
# https://scholar.google.com//citations?hl=en&user=EuvREFgAAAAJ

# %%
df = pd.DataFrame(data)
display(df)
# Out:
#                               Name  \
# 0               Ahmad Fauzi Ismail
# 1   Ts. Dr. Haslinda Mohamed Kamar
# 2   Muhammad Zulkarnain Abd Rahman
# 3    Ir Dr Nor Aishah Saidina Amin
# 4                 Mukhlis A Rahman
# 5                 Dr. Zainal Salam
# 6                Shamsuddin Shahid
# 7        abdul halim mohamed yatim
# 8            WJ Lau (Woei-Jye Lau)
# 9                     Arshad Ahmad
# 10              Ahmad Fauzi Ismail
# 11  Ts. Dr. Haslinda Mohamed Kamar
# 12  Muhammad Zulkarnain Abd Rahman
# 13   Ir Dr Nor Aishah Saidina Amin
# 14                Mukhlis A Rahman
# 15                Dr. Zainal Salam
# 16               Shamsuddin Shahid
# 17       abdul halim mohamed yatim
# 18           WJ Lau (Woei-Jye Lau)
# 19                    Arshad Ahmad
#
#                                           Description Verified Email at  \
# 0   Advanced Membrane Technology Research Centre, ...            utm.my
# 1   Associate Professor, School of Mechanical Engi...            utm.my
# 2   Universiti Teknologi Malaysia, Delft universit...            utm.my
# 3            Professor, Universiti Teknologi Malaysia            utm.my
# 4   Advanced Membrane Technology Research Centre, ...  petroleum.utm.my
# 5   Professor of Power Electronics, Universiti Tek...        fke.utm.my
# 6   Associate Professor, Universiti Teknologi Mala...            utm.my
# 7                       Universiti teknologi malaysia        fke.utm.my
# 8   Advanced Membrane Technology Research Centre, ...            utm.my
# 9                       Universiti Teknologi Malaysia            utm.my
# 10  Advanced Membrane Technology Research Centre, ...            utm.my
# 11  Associate Professor, School of Mechanical Engi...            utm.my
# 12  Universiti Teknologi Malaysia, Delft universit...            utm.my
# 13           Professor, Universiti Teknologi Malaysia            utm.my
# 14  Advanced Membrane Technology Research Centre, ...  petroleum.utm.my
# 15  Professor of Power Electronics, Universiti Tek...        fke.utm.my
# 16  Associate Professor, Universiti Teknologi Mala...            utm.my
# 17                      Universiti teknologi malaysia        fke.utm.my
# 18  Advanced Membrane Technology Research Centre, ...            utm.my
# 19                      Universiti Teknologi Malaysia            utm.my
#
#    Cited By                                          Expertise  \
# 0     64516  [membrane technology, nanostructured materials...
# 1     43151  [Thermodynamics, Heat transfer, Thermal comfor...
# 2     16831                                   [Remote Sensing]
# 3     16025  [Applied catalysis, reaction engineering, biom...
# 4     15964            [Membrane Technology, Ceramic Membrane]
# 5     15391   [Power Electronics, Energy, Solar, Photovoltaic]
# 6     15177  [Water resources, Climate Change, Statistical ...
# 7     14906  [Power electronics, electrical drives, renewab...
# 8     14311  [Membrane, Thin Film Nanocomposite, Reverse Os...
# 9     13145  [Process Modeling, Process Safety, Process Con...
# 10    64516  [membrane technology, nanostructured materials...
# 11    43151  [Thermodynamics, Heat transfer, Thermal comfor...
# 12    16831                                   [Remote Sensing]
# 13    16025  [Applied catalysis, reaction engineering, biom...
# 14    15964            [Membrane Technology, Ceramic Membrane]
# 15    15391   [Power Electronics, Energy, Solar, Photovoltaic]
# 16    15177  [Water resources, Climate Change, Statistical ...
# 17    14906  [Power electronics, electrical drives, renewab...
# 18    14311  [Membrane, Thin Film Nanocomposite, Reverse Os...
# 19    13145  [Process Modeling, Process Safety, Process Con...
#
#                                                  Link
# 0   https://scholar.google.com//citations?hl=en&us...
# 1   https://scholar.google.com//citations?hl=en&us...
# 2   https://scholar.google.com//citations?hl=en&us...
# 3   https://scholar.google.com//citations?hl=en&us...
# 4   https://scholar.google.com//citations?hl=en&us...
# 5   https://scholar.google.com//citations?hl=en&us...
# 6   https://scholar.google.com//citations?hl=en&us...
# 7   https://scholar.google.com//citations?hl=en&us...
# 8   https://scholar.google.com//citations?hl=en&us...
# 9   https://scholar.google.com//citations?hl=en&us...
# 10  https://scholar.google.com//citations?hl=en&us...
# 11  https://scholar.google.com//citations?hl=en&us...
# 12  https://scholar.google.com//citations?hl=en&us...
# 13  https://scholar.google.com//citations?hl=en&us...
# 14  https://scholar.google.com//citations?hl=en&us...
# 15  https://scholar.google.com//citations?hl=en&us...
# 16  https://scholar.google.com//citations?hl=en&us...
# 17  https://scholar.google.com//citations?hl=en&us...
# 18  https://scholar.google.com//citations?hl=en&us...
# 19  https://scholar.google.com//citations?hl=en&us...

# %%
df.to_csv('/content/drive/MyDrive/ds_gs.csv', index=False)
