# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/special-topic-data-engineering/blob/main/assignment/data-scraping/submission/part2/Noctua/Part2_WebTextScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-search-results in /usr/local/lib/python3.10/dist-packages (2.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from google-search-results) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.4)

# %% [markdown]
# ## Test Scraping for 1 profile

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_scholar_author",
  "author_id": "QzgVq24AAAAJ",  #Author ID for Mohd Shahizan Othman
  "num": 100,
  "api_key": "c0eeb12894f66eb81c039cef78dcaac1b562867bf4230d226f45840c5a2fd62b"
}

search = GoogleSearch(params)
results = search.get_dict()
author = results["author"]

# %%
data = []
for response in results['articles']:
    title = response['title']
    author = response['authors']
    # pub_info = response['publication_info']
    # journal = response['journal']
    year = response['year']
    citations = response['cited_by']
    
    data.append({
        'Title': title,
        'Author': author,
        # 'Publication Info': pub_info,
        # 'Journal': journal,
        'Year': year,
        'Citations': citations
    })

# %%
df = pd.DataFrame(data)
# df.to_csv('google_scholar_data.csv', index=False)
df
# Out:
#                                                 Title  \
# 0   The impact of social media use on academic per...
# 1   The improvement of students' academic performa...
# 2   A model of factors affecting learning performa...
# 3   The role of social media for collaborative lea...
# 4   Use of e-learning by university students in Ma...
# ..                                                ...
# 95  Enterprise ontology based knowledge map for im...
# 96  The parallel AGE variances method for temperat...
# 97  Integrated approach to knowledge management in...
# 98  Improving utility accrual scheduling algorithm...
# 99  Pembangunan Apilikasi Web Menggunakan Active S...
#
#                                                Author  Year  \
# 0                                W Al-Rahmi, M Othman  2013
# 1                     WM Al-Rahmi, MS Othman, MA Musa  2014
# 2    WM Al-Rahmi, N Alias, MS Othman, VI Marin, G Tur  2018
# 3                     W Al-Rahmi, MS Othman, LM Yusuf  2015
# 4   WM Al-Rahmi, N Alias, MS Othman, AI Alzahrani,...  2018
# ..                                                ...   ...
# 95                   MA Musa, MS Othman, WM Al-Rahimi  2013
# 96  LM Yusuf, N Alias, MSB Ghouse, SM Shamsuddin, ...  2011
# 97                          J Salim, M Mohd, M Othman  2011
# 98         I Ahmad, M Othman, Z Zulkarnain, MF Othman  2008
# 99       MS Othman, S Miskon, SNHS Abdullah, LM Yusuf  2006
#
#                                             Citations
# 0   {'value': 317, 'link': 'https://scholar.google...
# 1   {'value': 243, 'link': 'https://scholar.google...
# 2   {'value': 233, 'link': 'https://scholar.google...
# 3   {'value': 200, 'link': 'https://scholar.google...
# 4   {'value': 187, 'link': 'https://scholar.google...
# ..                                                ...
# 95  {'value': 3, 'link': 'https://scholar.google.c...
# 96  {'value': 3, 'link': 'https://scholar.google.c...
# 97  {'value': 3, 'link': 'https://scholar.google.c...
# 98  {'value': 3, 'link': 'https://scholar.google.c...
# 99  {'value': 3, 'link': 'https://scholar.google.c...
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Scraping UTM FoC authors

# %%
from serpapi import GoogleSearch
from urllib.parse import urlsplit, parse_qsl

params = {
  "engine": "google_scholar_profiles",
  "mauthors": "faculty of computing, universiti teknologi malaysia",
  "api_key": "c0eeb12894f66eb81c039cef78dcaac1b562867bf4230d226f45840c5a2fd62b"
}

search = GoogleSearch(params)

data = []

# %%
profiles_is_present = True
while profiles_is_present:

    results = search.get_dict()
    for response in results['profiles']:
    
        data.append({
            'Name': response['name'],
            'Author ID': response['author_id'],
            'Email': response.get('email', 'N/A')
        })
   
    
    # if next page in SerpApi pagination -> update params to new a page results.
    # if no next page -> exit the while loop.
    if "next" in results.get("pagination", []):
        search.params_dict.update(dict(parse_qsl(urlsplit(results.get("pagination").get("next")).query)))
    else:
        profiles_is_present = False

# %%
df = pd.DataFrame(data)
# df.to_csv('google_scholar_data.csv', index=False)
df
# Out:
#                          Name     Author ID                          Email
# 0        Waleed Al-Rahmi, PhD  jEJuIWAAAAAJ                            N/A
# 1        Mohd Shahizan Othman  QzgVq24AAAAJ       Verified email at utm.my
# 2            Dayang NA Jawawi  4zE7K1YAAAAJ       Verified email at utm.my
# 3    Bander Ali Saleh Al-rimy  8vIXgG8AAAAJ       Verified email at utm.my
# 4    Syed Hamid Hussain Madni  MUUFa60AAAAJ       Verified email at utm.my
# ..                        ...           ...                            ...
# 57  Samira Fotoohifiroozabadi  a1TiuEAAAAAJ                            N/A
# 58           MOHD AZIM ZAINAL  O6tdLNwAAAAJ  Verified email at uitm.edu.my
# 59            Syazwa Mad Jais  DvTQ6_cAAAAJ  Verified email at live.utm.my
# 60     Nurul Raudhah Zulkifli  QCHJR_gAAAAJ                            N/A
# 61       Zulwaqar Zain Mohtar  Was13OMAAAAJ  Verified email at live.utm.my
#
# [62 rows x 3 columns]

# %% [markdown]
# ## Scrape any and all pages available for query "faculty of computing, universiti teknologi malaysia"

# %%
from serpapi import GoogleSearch
from urllib.parse import urlsplit, parse_qsl

params = {
  "engine": "google_scholar",
  "q": "faculty of computing, universiti teknologi malaysia", 
  "api_key": "c0eeb12894f66eb81c039cef78dcaac1b562867bf4230d226f45840c5a2fd62b"
}

search = GoogleSearch(params)
data_foc_utm = []

# %%
profiles_is_present = True
while profiles_is_present:

    results = search.get_dict()
    for response in results['organic_results']:
    
        data_foc_utm.append({
            'Title': response.get('title', 'N/A'),
            'Link': response.get('link', 'N/A'),
            'Snippet': response.get('snippet', 'N/A'),
            'Resources': response.get('resources', 'N/A'),
            'Publication Info': response.get('publication_info', 'N/A')
        })
   
    
    # if next page in SerpApi pagination -> update params to new a page results.
    # if no next page -> exit the while loop.
    if "next" in results.get("pagination", []):
        search.params_dict.update(dict(parse_qsl(urlsplit(results.get("pagination").get("next")).query)))
    else:
        profiles_is_present = False
        
#There will be error since the API key only can search up to 100 for free users
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-de5e762d69f1> in <cell line: 2>()
#       3
#       4     results = search.get_dict()
# ----> 5     for response in results['organic_results']:
#       6
#       7         data_foc_utm.append({
#
# KeyError: 'organic_results'

# %%
import pandas as pd
df_gs = pd.DataFrame(data_foc_utm)
df_gs
# Out:
#                                                  Title  \
# 0    … Learning Preferences of Students at Faculty ...
# 1    Use of e-learning by university students in Ma...
# 2    Timetable scheduling system using genetic algo...
# 3    The effectiveness of using e-learning in Malay...
# 4    A new algorithm for improving the low contrast...
# ..                                                 ...
# 915  Information Security Curriculum Framework at U...
# 916  SISTEM MAKLUMAT PENGURUSAN TADIKA SRI AYU PEND...
# 917  Pakej Pembelajaran Matapelajaran Kemahiran Hid...
# 918      Sistem Pendaftaran Dan Saman Kenderaan Di UTM
# 919  Kajian Ke Atas Teknik Pembelajaran Secara Adap...
#
#                                                   Link  \
# 0    https://www.researchgate.net/profile/Faiz-Zulk...
# 1    https://ieeexplore.ieee.org/abstract/document/...
# 2    https://ijic.utm.my/index.php/ijic/article/vie...
# 3    https://www.mcser.org/journal/index.php/mjss/a...
# 4    https://onlinelibrary.wiley.com/doi/abs/10.100...
# ..                                                 ...
# 915  http://eprints.utm.my/id/eprint/11239/6/AbArif...
# 916                                                N/A
# 917                                                N/A
# 918                                                N/A
# 919                                                N/A
#
#                                                Snippet  \
# 0    … of students from two different faculties at ...
# 1    … the bachelor’s degree in computer science fr...
# 2    … Abstract—Current timetable scheduling system...
# 3    … the action of acquiring knowledge through co...
# 4    Contrast is a distinctive visual attribute tha...
# ..                                                 ...
# 915  … Obviously our industry needs computer securi...
# 916
# 917
# 918
# 919
#
#                                              Resources  \
# 0    [{'title': 'researchgate.net', 'file_format': ...
# 1    [{'title': 'ieee.org', 'file_format': 'PDF', '...
# 2    [{'title': 'utm.my', 'file_format': 'PDF', 'li...
# 3    [{'title': 'mcser.org', 'file_format': 'PDF', ...
# 4                                                  N/A
# ..                                                 ...
# 915  [{'title': 'utm.my', 'file_format': 'PDF', 'li...
# 916                                                N/A
# 917                                                N/A
# 918                                                N/A
# 919                                                N/A
#
#                                       Publication Info
# 0    {'summary': 'F Zulkifli, A Fadhlullah, N Abu B...
# 1    {'summary': 'WM Al-Rahmi, N Alias, MS Othman, ...
# 2    {'summary': 'HK Mammi, LY Ying - International...
# 3    {'summary': 'WM Al-Rahmi, MS Othman, LM Yusuf ...
# 4    {'summary': 'Z Al‐Ameen, G Sulong - Scanning, ...
# ..                                                 ...
# 915  {'summary': 'AAS Arifin - 2009 - eprints.utm.my'}
# 916  {'summary': 'RNA Raja Abdul Manan - 2002 - UNI...
# 917  {'summary': 'NIKSH MAT ISA - 2003 - Universiti...
# 918  {'summary': 'KB Ja'affar - 2008 - Universiti T...
# 919  {'summary': 'H Yaacob - 1999 - Universiti Tekn...
#
# [920 rows x 5 columns]

# %%
df_gs.to_csv('GScholar_Scrape.csv', index=False)

# %% [markdown]
# ## Export to MongoDB database

# %%
# !pip install pymongo
from pymongo import MongoClient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.3.0)

# %%
# !pip install pyngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyngrok
#   Downloading pyngrok-6.0.0.tar.gz (681 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.2/681.2 kB 29.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-6.0.0-py3-none-any.whl size=19879 sha256=c1a9705c46e38ffd8695ecb81ff37210a641357424bc974471b7740dc7abee81
#   Stored in directory: /root/.cache/pip/wheels/5c/42/78/0c3d438d7f5730451a25f7ac6cbf4391759d22a67576ed7c2c
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-6.0.0

# %%
import pymongo

# %%
# Connect to MongoDB
client = pymongo.MongoClient("mongodb+srv://afifhazmiearsyad:abc123456789@noctua.bw9bvzx.mongodb.net/test")
db = client['Noctua']
collection = db['Google Scholar']

data = df_gs.to_dict(orient='records')
collection.insert_many(data)
