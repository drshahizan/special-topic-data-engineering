# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/special-topic-data-engineering/blob/main/Assignment/API/submission/Noctua/PenangPrayerTime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing necessary libraries including requests and json to pull data from the source / url.

# %%
import requests
import json
import pandas as pd
import csv
from google.colab import files

# %%
city = input("Enter your city: ")
# Out:
# Enter your city: Penang

# %%
url = "http://api.aladhan.com/v1/calendarByCity/2023?city="+ city + "&country=Malaysia&method=11"
response = requests.get(url)
data = response.json()

# %%
month_count = 1
rows = []

while month_count <= len(data["data"]):
    for day in data['data']["%s" % month_count]:
        date = day['date']['readable']
        islamicdate = day['date']['hijri']['date']
        fajr = day['timings']['Fajr']
        sunrise = day['timings']['Sunrise']
        dhuhr = day['timings']['Dhuhr']
        asr = day['timings']['Asr']
        maghrib = day['timings']['Maghrib']
        isha = day['timings']['Isha']
        row = {'City': city, 'Date': date, 'Islamic Date': islamicdate, 'Subuh': fajr, 'Syuruk': sunrise, 'Zohor': dhuhr, 'Asar': asr, 'Maghrib': maghrib, 'Isya': isha}
        rows.append(row)

    month_count += 1

# %%
#row = {'City': city, 'Date': date, 'Islamic Date': islamicdate, 'Subuh': fajr, 'Syuruk': sunrise, 'Zohor': dhuhr, 'Asar': asr, 'Maghrib': maghrib, 'Isya': isha}
#rows.append(row)

# %%
df = pd.DataFrame(rows, columns=['City', 'Date', 'Islamic Date', 'Subuh', 'Syuruk', 'Zohor', 'Asar', 'Maghrib', 'Isya'])

# %%
print(df)

filePrayer = 'Waktu_Solat_'+ city + '.csv'

df.to_csv(filePrayer, index=False)
files.download(filePrayer)
# Out:
#        City         Date Islamic Date        Subuh       Syuruk        Zohor  \
# 0    Penang  01 Jan 2023   08-06-1444  06:04 (+08)  07:28 (+08)  13:22 (+08)
# 1    Penang  02 Jan 2023   09-06-1444  06:05 (+08)  07:28 (+08)  13:23 (+08)
# 2    Penang  03 Jan 2023   10-06-1444  06:05 (+08)  07:28 (+08)  13:23 (+08)
# 3    Penang  04 Jan 2023   11-06-1444  06:06 (+08)  07:29 (+08)  13:23 (+08)
# 4    Penang  05 Jan 2023   12-06-1444  06:06 (+08)  07:29 (+08)  13:24 (+08)
# ..      ...          ...          ...          ...          ...          ...
# 360  Penang  27 Dec 2023   14-06-1445  06:02 (+08)  07:25 (+08)  13:20 (+08)
# 361  Penang  28 Dec 2023   15-06-1445  06:02 (+08)  07:26 (+08)  13:20 (+08)
# 362  Penang  29 Dec 2023   16-06-1445  06:03 (+08)  07:26 (+08)  13:21 (+08)
# 363  Penang  30 Dec 2023   17-06-1445  06:03 (+08)  07:27 (+08)  13:21 (+08)
# 364  Penang  31 Dec 2023   18-06-1445  06:04 (+08)  07:27 (+08)  13:21 (+08)
#
#             Asar      Maghrib         Isya
# 0    16:45 (+08)  19:17 (+08)  20:31 (+08)
# 1    16:45 (+08)  19:17 (+08)  20:32 (+08)
# 2    16:46 (+08)  19:18 (+08)  20:32 (+08)
# 3    16:46 (+08)  19:18 (+08)  20:33 (+08)
# 4    16:47 (+08)  19:19 (+08)  20:33 (+08)
# ..           ...          ...          ...
# 360  16:42 (+08)  19:14 (+08)  20:29 (+08)
# 361  16:43 (+08)  19:14 (+08)  20:29 (+08)
# 362  16:43 (+08)  19:15 (+08)  20:30 (+08)
# 363  16:44 (+08)  19:15 (+08)  20:30 (+08)
# 364  16:44 (+08)  19:16 (+08)  20:31 (+08)
#
# [365 rows x 9 columns]

# %%
! pip install pymongo
from pymongo import MongoClient
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.9/dist-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from pymongo) (2.3.0)

# %%
# Create a Mongo DB client
client = MongoClient('mongodb+srv://admin:admin@prayercluster.lrzhldw.mongodb.net/test')

# Select the existing database to store the csv files
db = client["prayer"]

# Select the existing database collection to group the csv files
collection = db["Penang"]

# %%
df.reset_index(inplace = True)
Data_dictionary=df.to_dict('records')

print(Data_dictionary)
# Out:
# [{'index': 0, 'City': 'Penang', 'Date': '01 Jan 2023', 'Islamic Date': '08-06-1444', 'Subuh': '06:04 (+08)', 'Syuruk': '07:28 (+08)', 'Zohor': '13:22 (+08)', 'Asar': '16:45 (+08)', 'Maghrib': '19:17 (+08)', 'Isya': '20:31 (+08)'}, {'index': 1, 'City': 'Penang', 'Date': '02 Jan 2023', 'Islamic Date': '09-06-1444', 'Subuh': '06:05 (+08)', 'Syuruk': '07:28 (+08)', 'Zohor': '13:23 (+08)', 'Asar': '16:45 (+08)', 'Maghrib': '19:17 (+08)', 'Isya': '20:32 (+08)'}, {'index': 2, 'City': 'Penang', 'Date': '03 Jan 2023', 'Islamic Date': '10-06-1444', 'Subuh': '06:05 (+08)', 'Syuruk': '07:28 (+08)', 'Zohor': '13:23 (+08)', 'Asar': '16:46 (+08)', 'Maghrib': '19:18 (+08)', 'Isya': '20:32 (+08)'}, {'index': 3, 'City': 'Penang', 'Date': '04 Jan 2023', 'Islamic Date': '11-06-1444', 'Subuh': '06:06 (+08)', 'Syuruk': '07:29 (+08)', 'Zohor': '13:23 (+08)', 'Asar': '16:46 (+08)', 'Maghrib': '19:18 (+08)', 'Isya': '20:33 (+08)'}, {'index': 4, 'City': 'Penang', 'Date': '05 Jan 2023', 'Islamic Date': '12-06-1444', 'Subuh': '06:06 (+08)', 'Syuruk': '07:29 (+08)', 'Zohor': '13:24 (+08)', 'Asar': '16:47 (+08)', 'Maghrib': '19:19 (+08)', 'Isya': '20:33 (+08)'}, {'index': 5, 'City': 'Penang', 'Date': '06 Jan 2023', 'Islamic Date': '13-06-1444', 'Subuh': '06:07 (+08)', 'Syuruk': '07:30 (+08)', 'Zohor': '13